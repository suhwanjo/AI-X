# %%
# 시리즈 = col , 데이터프레임 = Matrix
import pandas as pd

# %% [markdown]
# # 객체 생성
#     sr = pd.Series(dictionary or list,index=[''])
#
#     df = pd.DataFrame(dictionary or list,index=[''],columns=['']
#
# # 행 선택
#     df.loc['행에서','열찾기'] == dr.iloc[0]                             # loc은 마지막 포함, iloc은 제외
# # 열 선택
#     df['영어'] == df.영어
#
# # 행 설정
#     df.set_index(''or[''],inplace=True)
#
#     df.reindex(newindex)
#
#     df.reset_index()                                                    # 정수형으로 초기화
#
#     df.sort_index(by='열',ascending=False)                              # 열을 기준으로 내림차순 정렬
#
#     df.transpose() == df.T                                              # 전치
#
# # 파일 불러오기
#     pd.read_cvs(filename)
#
#     df.to_csv(filename)
#
#     pd.read_excel(filname,engine='openpyxl')
#
#     pd.read_json(filename)                                               # key : value 구조
#
# # 그 외
#     sr['index':'index']
#
#     idx = sr.index                                                       # 행
#
#     val = sr.value                                                       # 열
#
#     df.rename(columns={'now':'new','now':'new'},inplace=True)            # inplace = True옵션은 원본 객체 변경
#
#     df.drop(['',''],axis=0,inplace=True)                                 # 행,열 삭제
#
#     print(df.shape)                                                      # (행,열)
#
#     print(df.dtypes)                                                     # 각 열의 자료형
#
#     df.info()                                                            # 기본 정보
#
#     df.describe()                                                        # include='all'옵션은 산술 데이터 값만 표시
#
#     df.value_counts()                                                    # 각 열의 데이터 개수 확인
#
#     df.mean,median,max,min,std,corr()
#
#     df.columns.map(int)                                                  # 열의 자료형을 정수형으로 변경

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Matplotlib
#     plt.style.use('ggplot')                                              # 스타일
#
#     fig=plt.figure(figsize=(x,y))                                        # 가로x인치, 세로y인치
#
#     ax1=fig.add_subplot(2,1,1)                                           # 2행 1열의 첫번째 subplot
#
#     ax2=fig.add_subplot(2,1,2)
#
# # 그래프
#     plt.plot(x,y) == plt.plot(dataframe,marker='o',
#                               markerfacecolor='green',
#                               markersize=10,color='olive',linewidth=2,label='') # 범례
#
#     fig.plot(kind='area',stacked=False,
#              alpha=0.
#              2,figsize=(10,20))                                          # 면적 그래프, 누적X
#
#     fig.plot(kind='bar',figsize(10,20),
#              width=0.7,
#              color=['','','',''])                                        # 가로막대 = barh
#
#     fig.plot(kind='hist',bins=10,
#              color='coral',
#              figsize=(10.20))                                            # bins = 구간 개수
#
#     fig.plot(kind='scatter',x='',y='',c='',s=10,
#              figsize=(10,20))                                            # c=점색상, s=점크기 # s=cylinders_size 옵션은 버블차트
#
# # 파이 차트
#     df.['count'] = 1
#
#     df_origin = df.groupby('열').sum()
#
#     df_origin['count'].plot(kind='pie',figsize=(7,5),
#                             autopct='%1.1f%%',                           # 퍼센트 표시
#                             startangle=10,                               # 파이 조각을 나누는 시작 각도
#                             colors=['','',''])
#
#     plt.axis('equal')                                                    # 파이 차트의 비율을 같게(원에 가깝게) 조정
#
# # 박스 플롯
#     fig.boxplot(x=df[df['origin']==1]['mpg'],labels=['','',''])          # origin 값이 1인 mpg열 # vert = False옵션은 수평
#
#     plt.legend(loc='best',fontsize=10)                                   # 범례 표시
#
#     plt.title(titlename)                                                 # 제목
#
#     plt.xlabel('',size=10)                                               # x축 라벨 설정
#
#     plt.xticks(size=10,rotation=90)                                      # x축 라벨 90도 회전  # 두개 합치면
#
#     plt.xticklabels(dataframe.index,rotation=90)                         # 라벨 설정 + 회전
#
#     plt.ylim(5000,8000)                                                  # y축 범위 지정

# %% [markdown]
# # Matplotlib 한글 폰트 오류 해결
#
# # 한글 폰트 파일 다운 후 파이썬 파일과 같은 폴더에 저장

# %%
    from matplotlib import font_manager, rc

# %% [markdown]
#     font_path = '폰트 파일 위치'
#
#     font_name = font_manager.FontProperties(fname=font_path).get_name()
#
#     rc('font',family=font_name)

# %%
import seaborn as sns

# %% [markdown]
# # Seaborn
# # 히트맵
#     table = titanic.pivot_table(index=[''],cloumns=[''],aggfunc='size')   # 데이터 값의 크기를 기준으로 집계
#
#     sns.heatmap(table,annot=True,fmt='d',                                 # 데이터 값 표시, 정수형 포맷
#                 cmap='YLGnBu',                                            # 컬러 맵
#                 linewidth=5,                                              # 구분 선
#                 cbar=False)                                               # 컬러 바 표시 여부

# %%
import folium

# %% [markdown]
# # Folium
#
# # 지도 생성
#     seoul_map = folium.map(location=[위도,경도],zoom_start=12)             # 위도,경도 기준, 12의 화면 확대 비율
#
# # 스타일
#     tiles = 'stamen Terrain' # 지형 파악 용이,'Stamen Toner'               # 도로망 파악 용이
#
# # 지도에 마커 표
#     for name,lat,lng in zip(df.index,df.위도,df.경도):
#         folium.Marker([lat,lng], popup = name # 마커 클릭 시 팝업창에 표시).add_to(seoul_map)
# # 원 마커 표시
#     folium.CircleMarker([lat,lng],
#                         radius=10,                                          # 원의 반지름
#                         color='brown',                                      # 원의 둘레 색상
#                         fill=True,
#                         fill_color='coral',                                 # 원을 채우는 색
#                         popup=name).add_to(seoul_map)
#
#
#     file_path = './경기도인구데이터.xlsx'
#
#     df = pd.read_excel(file_path, index_col='구분', engine= 'openpyxl')
#
#     df.columns = df.columns.map(str)
#
#     geo_path = './경기도행정구역경계.json'
#
#     try:
#
#         geo_data = json.load(open(geo_path, encoding='utf-8'))
#
#     except:
#
#         geo_data = json.load(open(geo_path, encoding='utf-8-sig'))
#
#     g_map = folium.Map(location=[37.5502,126.982],
#                        tiles='Stamen Terrain', zoom_start=9)
#
#     year = '2017'
#
# # 단계구분도 표시
#     folium.Choropleth(geo_data=geo_data,                                      # 지도 경계
#                      data = df[year],                                         # 표시하려는 데이터
#                      columns = [df.index, df[year]],                          # 열 지정
#                      fill_color='YlOrRd', fill_opacity=0.7, line_opacity=0.3,
#                      threshold_scale=[10000, 100000, 300000, 500000, 700000],
#                      key_on='feature.properties.name',
#                      ).add_to(g_map)
#
#     g_map.save('./gyonggi_population_' + year + '.html')

# %% [markdown]
# # 데이터 전처리
#
# # 누락 데이터 확인
#     df[''].value_counts(dropna = False),isnull(),notnull()
#
# # 누락 데이터 제거
#     df.dropna(axis=1,thresh=500)                             # NaN이 500개 이상인 열 삭제
#
#     df.dropna(subset=['age'],how='any',axis=0)               # age열에 NaN이 하나라도 존재하는 행 삭제
#
# # 누락 데이터 치환
#     mean_age = df['age'].mean()
#
#     df['age'].fillna(mean_age,inplace=True)                  # age열의 NaN값을 평균값으로 치환
#                                                              # method='ffill은 직전행으로, bfill은 다음행으로 치환
#
# # 중복 데이터 확인,제거
#     df.duplicated(), df.drop_duplicated(aubset=['',''])      # subset 옵션은 특정 열을 기준으로 중복 행 삭제
#
# # 자료형 변환
#     df['horsepower'].replace('?', np.nan, inplace=True)      # '?'을 np.nan으로 변경
#
#     df.dropna(subset=['horsepower'], axis=0, inplace=True)   # 누락데이터 행을 삭제
#
#     df['horsepower'] = df['horsepower'].astype('float')      # 문자열을 실수형으로 변환
#
#     pd.to_datetime(df[''])                                   # 객체를 판다스 Timestamp로 변환
#
#     df.to_period(freq='D')                                   # 객체를 일정한 기간을 나타내는 Period 객체로 변환 D=1일, M=1달, Y=1년 기간
#
# # 날짜 데이터 분리
#     df['Year'] = df['new_Date'].dt.year                      # dt 속성을 이용하여 new_Date 열의 년월일 정보를 년, 월, 일로 구분
#     df['Month'] = df['new_Date'].dt.month
#     df['Day'] = df['new_Date'].dt.day

# %% [markdown]
#     sorted(columns)                                           # 알파벳 순으로 정렬 reversed() = 기존 순서의 역순으로 정렬
#
#     datas = df['연도'].str.split('-')                         # 문자열을 '-' 으로 분리
#
#     df['연'] = datas.str.get(0)                               # 분리된 datas변수의 첫번째 인덱스 값(연도)
#
#     titanic['a'].isin([3,4,5])                                # a 행에서 3,4,5값이 있는 행은 참 반환
#
# # 데이터프레임 합치기
#     pd.concat([df1,df2],ignore_index=True)                    # 두 데이터프레임을 행 방향으로 병합하되 기존 행 인덱스 무시하고 새로운 행                                                                 # 인덱스 설정
#
#     pd.merge(df1,df2,how='outer',left_on='a',right_on='b')    # 두 데이터프레임의 키를 다르게 설정하여 합집합으로 병합
#
#     df1.join(df2)                                             # 두 데이터프레임의 행 인덱스를 기준으로 병합
#
# # 그룹 연산
#     grouped = df.groupby(['class','sex'])                     # class열, sex열의 값을 기준으로 그룹 나누기(6개의 조합 가능)
#
#     grouped.agg(새로운열이름=('age','sum'))                   # 그룹 객체에서 함수 실행 후 새로운 열이름으로 열 생성
#
#     for key,group in grouped:                                 # 그룹 객체를 iteration으로 출력
#         print(group.head())
#
#     grouped.get_group(('a','b'))                              # 특정 그룹 선택 가능
#
#     grouped.filter(lambda x: len(x) >= 200)                   # 조건을 충족하는 그룹의 데이터만 추출, (lambda 매개변수: 반환값)
#
# # 피벗 테이블
#     pd.pivot_table(df,                                        # 피벗할 데이터프레임                       age
#                    index=['class']                            # 행 위치에 들어갈 열               class   0  1
#                    columns='survived'                         # 열 위치에 들어갈 열               first
#                    values=['age']                             # 데이터로 사용할 열                second
#                    aggfunc=['mean']                           # 데이터 집계 함수                  thrid
