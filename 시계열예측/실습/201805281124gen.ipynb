# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from scipy import stats

# %%
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %%
df18 = pd.read_csv('test2018.csv', sep=',', index_col=0)
df19 = pd.read_csv('test2019.csv', sep=',', index_col=0)

# %%
a=df18['총생활인구수']
b=df19['총생활인구수']

# %% [markdown]
# # 5월 28일 이상치

# %%
plt.figure(figsize=(25,10))
#plt.plot(df17['총생활인구수'], data = df17)
plt.plot(a[3500:3600], data = df18) # 2018-5-28 전후 하루 더해서 평균

# %%
df18_0528=(df18['총생활인구수'].iloc[3528-24:3528].values+df18['총생활인구수'].iloc[3528+24:3528+48].values)/2

# %%
df18['총생활인구수'].iloc[3528:3528+24]=df18_0528

# %%
plt.figure(figsize=(25,10))
#plt.plot(df17['총생활인구수'], data = df17)
plt.plot(a[3500:3600], data = df18) # 2018-5-28 전후 하루 더해서 평균
plt.ylim(35000,65000)
# Out:
# (35000.0, 65000.0)

# %% [markdown]
# # 11월 24~25일 이상치

# %%
plt.figure(figsize=(25,10))
#plt.plot(df17['총생활인구수'], data = df17)
plt.plot(a[7800:8000], data = df18) # 2018-11-24 전후 이틀 더해서 평균

# %%
df18_1124=(df18['총생활인구수'].iloc[7848-48:7896-48].values+df18['총생활인구수'].iloc[7848+48:7896+48].values)/2

# %%
df18['총생활인구수'].iloc[7848:7896]=df18_1124

# %%
plt.figure(figsize=(25,10))
#plt.plot(df17['총생활인구수'], data = df17)
plt.plot(a[7800:8000], data = df18) # 2018-11-24 전후 이틀 더해서 평균
plt.ylim(25000,65000)
# Out:
# (25000.0, 65000.0)

# %%
df18.to_csv('test2018new.csv')
