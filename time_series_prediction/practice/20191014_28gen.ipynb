# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from scipy import stats

# %%
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %%
df17 = pd.read_csv('test2017.csv', sep=',', index_col=0)
df18 = pd.read_csv('test2018.csv', sep=',', index_col=0)
df19 = pd.read_csv('test2019.csv', sep=',', index_col=0)
df20 = pd.read_csv('test2020.csv', sep=',', index_col=0)
df21 = pd.read_csv('test2021.csv', sep=',', index_col=0)

# %%
print(stats.pearsonr(df19['총생활인구수'].iloc[6552:6864], df17['총생활인구수'].iloc[6552:6864]))
print(stats.pearsonr(df19['총생활인구수'].iloc[6552:6864], df18['총생활인구수'].iloc[6552:6864]))
print(stats.pearsonr(df19['총생활인구수'].iloc[6552:6864], df20['총생활인구수'].iloc[6552+24:6864+24]))
print(stats.pearsonr(df19['총생활인구수'].iloc[6552:6864], df21['총생활인구수'].iloc[6552:6864]))
# Out:
# (0.4987335060086364, 5.033407597187641e-21)
# (0.9336315159126775, 3.0029559137148265e-140)
# (0.5940861637851504, 3.7680711700898768e-31)
# (0.7001851073962202, 2.8081418670298345e-47)

# %%
plt.figure(figsize=(20,4))
plt.plot(df19['총생활인구수'].iloc[6552:6864], data = df19)

# %%
newdf19=np.zeros(8760)

# %%
newdf19[0:6888]=df19['총생활인구수'].iloc[0:6888]

# %% [markdown]
# # 2018년 10/15~10/28일로 대체

# %%
newdf19[6888:6888+312]=df18['총생활인구수'].iloc[6888:6888+312] # 대체

# %%
newdf19[6888+312:8760]=df19['총생활인구수'].iloc[6888:8448]

# %%
newdf19.shape
# Out:
# (8760,)

# %%
df19.shape
# Out:
# (8448, 31)

# %%
df=df19.iloc[6552:6983]
plt.figure(figsize=(20,4))
plt.plot(df['총생활인구수'], data = df)

# %%
df2=newdf19[6552:6983+312]
plt.figure(figsize=(20,4))
plt.plot(df2, data = df2)

# %% [markdown]
# # 아무 데이터에다 대입

# %%
df18 = pd.read_csv('test2018.csv', sep=',', index_col=0)

# %%
df18['총생활인구수']=newdf19

# %%
df18
# Out:
#          기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0     20180101      0  40817.7171       846.9405         557.4737
# 1     20180101      1  40685.6385       901.9533         593.6502
# 2     20180101      2  41398.4914       850.1169         559.5622
# 3     20180101      3  41464.8976       854.0133         562.1243
# 4     20180101      4  41619.0919       846.3957         557.1146
# ...        ...    ...         ...            ...              ...
# 8755  20181231     19  36001.3650       868.6073         571.7216
# 8756  20181231     20  35990.6160       894.3724         588.6648
# 8757  20181231     21  36210.8996       996.0327         655.5183
# 8758  20181231     22  36713.2088       867.6344         571.0818
# 8759  20181231     23  40809.2065       897.5760         590.7712
#
#       남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0            805.0263        1944.7949        2067.2479        1609.0168
# ...

# %%
df18.to_csv('test2019new.csv')
