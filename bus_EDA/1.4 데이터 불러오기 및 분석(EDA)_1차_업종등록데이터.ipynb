# %% [markdown]
# # 안녕하세요^^
# ## '서울시 생활정보 기반 대중교통 수요 분석 ' 과정에 오신 여러분을 환영합니다.
# * 본 과정에서는 실제 사례와 데이터를 기반으로 문제를 해결하는 전체 과정을 자기 주도형 실습으로 진행해볼 예정입니다.
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 분석부터 먼저 시작해보겠습니다.
# ## "구별 업종 등록 데이터" 를 확인해 보도록 하겠습니다

# %%
# 필요 라이브러리부터 설치합니다.
# %pip install pandas seaborn

# %% [markdown]
# ## 기본전제
# * 처음에 제공되는 기본/추가 데이터는 'raw_data' 폴더에 있습니다.
#
# [기본 데이터]
# * business_type.csv
#
# [데이터 소개]
# * 서울 시 구별 등록 업종 상위 10개 데이터
#     * 택시운송업
#     * 한식일반음식점업
#     * 용달 화물자동차 운송업
#     * 부동산 중개 및 대리업
#     * 두발미용업
#     * 커피전문점
#     * 남녀용 겉옷 및 셔츠 도매업
#     * 기타주점업
#     * 일반 교과 학원
#     * 한식 육류요리 전문점
#
# [변수 소개]
# * 다수 업종 상위 1~10

# %% [markdown]
# ---

# %% [markdown]
# # 1.데이터 불러오기
# ## 모든 미니 프로젝트의 시작은 '데이터 불러오기' 부터라고 할 수 있습니다.
# + KeyPoint : 불러오고자 하는 데이터에 따라 자유롭게 변수로 지정할 수 있다.

# %% [markdown]
# ###  데이터 프레임을 불러오고 변수로 저장(여기서는 CSV 기준으로 진행)
# * csv : pd.read_csv("파일이름. csv")
# * txt : pd.read_csv("파일이름. csv", sep="구분자")
# * xlsx : pd.read_excel('파일이름.xlsx')
# * pickle : pd.read_pickle("파일이름.pkl") <br>
#  [참고] pickle은 파이썬의 모든 객체를 파일로 저장할 수 있는 방법으로 DataFrame,List,Dict 등 모든 객체 저장 가능(특히 sklearn라이브러리를 통해 모델을 학습시키고, 저장할 때 많이 사용)

# %% [markdown]
# ## 기본전제
# * 처음에 제공되는 데이터는 'raw_data' 폴더에 있습니다.
#
# [기본 데이터]
# * 1.4 business_type.csv
#
# [데이터 소개]
# * 서울시 업종 등록 데이터

# %% [markdown]
# #### [실습문제1] 데이터 로딩
# * '1.4 business_type.csv'파일을 'seoul_business' 변수에 저장하고 그 데이터를 확인하세요.
#     * 데이터 파일 로딩시 참고 사항
#         * 구분자(sep)는 ',' 입니다
#         * UTF-8 인코더를 사용해 주세요

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
import pandas as pd
seoul_business=pd.read_csv('1.4 business_type.csv',sep=',',encoding='UTF-8')

# %%
# 데이터 프레임의 Shape을 확인합니다.
seoul_business.shape
# Out:
# (451, 22)

# %% [markdown]
# ---

# %% [markdown]
# # 2.기본 정보 확인 및 클렌징
#
# + 데이터 클렌징 : 결측치, 이상치 등을 제거하여 데이터 분석 결과가 왜곡 되는 문제를 방지하기 위한 정제 과정

# %% [markdown]
# #### [실습문제2] 기본 정보 확인하기
# * 'seoul_moving' 데이터의 정보를 확인해보세요.
# * 'describe', 'info', 'head' 등 전부 활용해 보겠습니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

seoul_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   자치구           451 non-null    object
#  1   동             451 non-null    object
#  2   다수업종 상위10     451 non-null    object
#  3   다수업종 상위10.1   451 non-null    object
#  4   다수업종 상위10.2   451 non-null    object
#  5   다수업종 상위10.3   451 non-null    object
#  6   다수업종 상위10.4   451 non-null    object
#  7   다수업종 상위10.5   451 non-null    object
#  8   다수업종 상위10.6   451 non-null    object
#  9   다수업종 상위10.7   451 non-null    object
#  10  다수업종 상위10.8   451 non-null    object
#  11  다수업종 상위10.9   451 non-null    object
#  12  다수업종 상위10.10  451 non-null    object
#  13  다수업종 상위10.11  451 non-null    object
#  14  다수업종 상위10.12  451 non-null    object
#  15  다수업종 상위10.13  451 non-null    object
#  16  다수업종 상위10.14  451 non-null    object
#  17  다수업종 상위10.15  451 non-null    object
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

seoul_business.head(10)
# Out:
#    자치구    동 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3   다수업종 상위10.4  \
# 0  자치구    동     택시운송업       택시운송업  한식 일반 음식점업  한식 일반 음식점업  용달 화물자동차 운송업
# 1  자치구    동      사업체수        종사자수        사업체수        종사자수          사업체수
# 2   합계   합계    47,176      76,701      29,225     100,183        28,494
# 3  종로구   소계       215         215       1,548       5,912           618
# 4  종로구  사직동         7           7         230         982            12
# 5  종로구  삼청동         5           5          42         145             4
# 6  종로구  부암동        22          22          26         100             9
# 7  종로구  평창동        10          10          31         116            11
# 8  종로구  무악동        10          10          10          26           410
# 9  종로구  교남동        14          14          14          44             7
#
#     다수업종 상위10.5   다수업종 상위10.6   다수업종 상위10.7  ... 다수업종 상위10.10 다수업종 상위10.11  \
# 0  용달 화물자동차 운송업  부동산 중개 및 대리업  부동산 중개 및 대리업  ...        커피전문점        커피전문점
# ...

# %% [markdown]
# #### [실습문제3] 데이터 확인 및 처리
#
# * 데이터를 보았을때, 어느 데이터를 가져와야 할지 생각 해 봅시다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# 1행을 열이름으로 지정
seoul_business=pd.read_csv('1.4 business_type.csv',sep=',',encoding='UTF-8',header=1)

# %%
seoul_business.head(10)
# Out:
#    자치구    동   택시운송업 택시운송업.1 한식 일반 음식점업 한식 일반 음식점업.1 용달 화물자동차 운송업  \
# 0  자치구    동    사업체수    종사자수       사업체수         종사자수         사업체수
# 1   합계   합계  47,176  76,701     29,225      100,183       28,494
# 2  종로구   소계     215     215      1,548        5,912          618
# 3  종로구  사직동       7       7        230          982           12
# 4  종로구  삼청동       5       5         42          145            4
# 5  종로구  부암동      22      22         26          100            9
# 6  종로구  평창동      10      10         31          116           11
# 7  종로구  무악동      10      10         10           26          410
# 8  종로구  교남동      14      14         14           44            7
# 9  종로구  가회동       9       9         57          270            7
#
#   용달 화물자동차 운송업.1 부동산 중개 및 대리업 부동산 중개 및 대리업.1  ...   커피전문점 커피전문점.1  \
# 0           종사자수         사업체수           종사자수  ...    사업체수    종사자수
# 1         29,356       24,013         42,636  ...  16,255  57,322
# ...

# %%
print(seoul_business.loc[0])
# Out:
# 자치구                   자치구
# 동                       동
# 택시운송업                사업체수
# 택시운송업.1              종사자수
# 한식 일반 음식점업           사업체수
# 한식 일반 음식점업.1         종사자수
# 용달 화물자동차 운송업         사업체수
# 용달 화물자동차 운송업.1       종사자수
# 부동산 중개 및 대리업         사업체수
# 부동산 중개 및 대리업.1       종사자수
# 두발미용업                사업체수
# 두발미용업.1              종사자수
# 커피전문점                사업체수
# 커피전문점.1              종사자수
# 남녀용 겉옷 및 셔츠 도매업      사업체수
# 남녀용 겉옷 및 셔츠 도매업.1    종사자수
# 기타주점업                사업체수
# 기타주점업.1              종사자수
# 일반 교과 학원             사업체수
# 일반 교과 학원.1           종사자수
# 한식 육류요리 전문점          사업체수
# 한식 육류요리 전문점.1        종사자수
# Name: 0, dtype: object

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# 열 이름 변경
seoul_business.rename(columns={'택시운송업':'택시운송업 사업체수',
                               '택시운송업.1':'택시운송업 종사자수',
                               '한식 일반 음식점업':'한식 일반 음식점업 사업체수',
                               '한식 일반 음식점업.1':'한식 일반 음식점업 종사자수',
                               '용달 화물자동차 운송업':'용달 화물자동차 운송업 사업체수',
                               '용달 화물자동차 운송업.1':'용달 화물자동차 운송업 종사자수',
                               '부동산 중개 및 대리업':'부동산 중개 및 대리업 사업체수',
                               '부동산 중개 및 대리업.1':'부동산 중개 및 대리업 종사자수',
                               '두발미용업':'두발미용업 사업체수',
                               '두발미용업.1':'두발미용업 종사자수',
                               '커피전문점':'커피전문점 사업체수',
                               '커피전문점.1':'커피전문점 종사자수',
                               '남녀용 겉옷 및 셔츠 도매업':'남녀용 겉옷 및 셔츠 도매업 사업체수',
                               '남녀용 겉옷 및 셔츠 도매업.1':'남녀용 겉옷 및 셔츠 도매업 종사자수',
                               '기타주점업':'기타주점업 사업체수',
                               '기타주점업.1':'기타주점업 종사자수',
                               '일반 교과 학원':'일반 교과 학원 사업체수',
                               '일반 교과 학원.1':'일반 교과 학원 종사자수',
                               '한식 육류요리 전문점':'한식 육류요리 전문점 사업체수',
                               '한식 육류요리 전문점.1':'한식 육류요리 전문점 종사자수'},inplace=True)

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business.columns
# Out:
# Index(['자치구', '동', '택시운송업 사업체수', '택시운송업 종사자수', '한식 일반 음식점업 사업체수',
#        '한식 일반 음식점업 종사자수', '용달 화물자동차 운송업 사업체수', '용달 화물자동차 운송업 종사자수',
#        '부동산 중개 및 대리업 사업체수', '부동산 중개 및 대리업 종사자수', '두발미용업 사업체수', '두발미용업 종사자수',
#        '커피전문점 사업체수', '커피전문점 종사자수', '남녀용 겉옷 및 셔츠 도매업 사업체수',
#        '남녀용 겉옷 및 셔츠 도매업 종사자수', '기타주점업 사업체수', '기타주점업 종사자수', '일반 교과 학원 사업체수',
#        '일반 교과 학원 종사자수', '한식 육류요리 전문점 사업체수', '한식 육류요리 전문점 종사자수'],
#       dtype='object')

# %%
# 사업체, 종사자 수 행과 합계,소계 행 제거
seoul_business=seoul_business.drop([0,1,2])

# %%
seoul_business.head(10)
# Out:
#     자치구            동 택시운송업 사업체수 택시운송업 종사자수 한식 일반 음식점업 사업체수 한식 일반 음식점업 종사자수  \
# 3   종로구          사직동          7          7             230             982
# 4   종로구          삼청동          5          5              42             145
# 5   종로구          부암동         22         22              26             100
# 6   종로구          평창동         10         10              31             116
# 7   종로구          무악동         10         10              10              26
# 8   종로구          교남동         14         14              14              44
# 9   종로구          가회동          9          9              57             270
# 10  종로구  종로1.2.3.4가동          1          1             565           2,396
# 11  종로구      종로5·6가동          6          6             176             542
# 12  종로구          이화동          4          4              71             395
#
#    용달 화물자동차 운송업 사업체수 용달 화물자동차 운송업 종사자수 부동산 중개 및 대리업 사업체수 부동산 중개 및 대리업 종사자수  \
# ...

# %%
seoul_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 3 to 449
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   자치구                   447 non-null    object
#  1   동                     447 non-null    object
#  2   택시운송업 사업체수            447 non-null    object
#  3   택시운송업 종사자수            447 non-null    object
#  4   한식 일반 음식점업 사업체수       447 non-null    object
#  5   한식 일반 음식점업 종사자수       447 non-null    object
#  6   용달 화물자동차 운송업 사업체수     447 non-null    object
#  7   용달 화물자동차 운송업 종사자수     447 non-null    object
#  8   부동산 중개 및 대리업 사업체수     447 non-null    object
#  9   부동산 중개 및 대리업 종사자수     447 non-null    object
#  10  두발미용업 사업체수            447 non-null    object
#  11  두발미용업 종사자수            447 non-null    object
#  12  커피전문점 사업체수            447 non-null    object
#  13  커피전문점 종사자수            447 non-null    object
#  14  남녀용 겉옷 및 셔츠 도매업 사업체수  447 non-null    object
# ...

# %%
# groupby 연산을 위한 처리

# 구 열은 임시로 저장
seoul_business_gu=seoul_business['자치구']
seoul_business_gu=seoul_business_gu.reset_index(drop=True)

# 구와 동 열을 제거
seoul_business=seoul_business.drop(['동','자치구'],axis=1)

# %%
# '-'는 없는 것으로 판단, 0으로 치환
seoul_business=seoul_business.replace({'-':0})

# %%
seoul_business.head()
# Out:
#   택시운송업 사업체수 택시운송업 종사자수 한식 일반 음식점업 사업체수 한식 일반 음식점업 종사자수 용달 화물자동차 운송업 사업체수  \
# 3          7          7             230             982                12
# 4          5          5              42             145                 4
# 5         22         22              26             100                 9
# 6         10         10              31             116                11
# 7         10         10              10              26               410
#
#   용달 화물자동차 운송업 종사자수 부동산 중개 및 대리업 사업체수 부동산 중개 및 대리업 종사자수 두발미용업 사업체수 두발미용업 종사자수  \
# 3                12                57                96         28         66
# 4                 4                 9                10          0          0
# 5                 9                17                26          8         10
# 6                11                33                52         19         28
# 7               416                12                17          9         10
#
# ...

# %%
seoul_business_gu
# Out:
# 0      종로구
# 1      종로구
# 2      종로구
# 3      종로구
# 4      종로구
#       ...
# 442    강동구
# 443    강동구
# 444    강동구
# 445    강동구
# 446    강동구
# Name: 자치구, Length: 447, dtype: object

# %%
# 숫자 표기 시 따옴표로 인해 자료형 변경이 불가능
seoul_business.astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [12], line 2
#       1 # 숫자 표기 시 따옴표로 인해 자료형 변경이 불가능
# ----> 2 seoul_business.astype('int64')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
# 저장
seoul_business.to_csv("seoul_business.csv", index = False)

# %%
# 읽어올 때 옵션으로 따옴표 제거
seoul_business=pd.read_csv('seoul_business.csv',sep=',',encoding='UTF-8',thousands=',')

# %%
seoul_business.head(10)
# Out:
#    택시운송업 사업체수  택시운송업 종사자수  한식 일반 음식점업 사업체수  한식 일반 음식점업 종사자수  \
# 0           7           7              230              982
# 1           5           5               42              145
# 2          22          22               26              100
# 3          10          10               31              116
# 4          10          10               10               26
# 5          14          14               14               44
# 6           9           9               57              270
# 7           1           1              565             2396
# 8           6           6              176              542
# 9           4           4               71              395
#
#    용달 화물자동차 운송업 사업체수  용달 화물자동차 운송업 종사자수  부동산 중개 및 대리업 사업체수  부동산 중개 및 대리업 종사자수  \
# 0                 12                 12                 57                 96
# 1                  4                  4                  9                 10
# ...

# %%
seoul_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   택시운송업 사업체수            447 non-null    int64
#  1   택시운송업 종사자수            447 non-null    int64
#  2   한식 일반 음식점업 사업체수       447 non-null    int64
#  3   한식 일반 음식점업 종사자수       447 non-null    int64
#  4   용달 화물자동차 운송업 사업체수     447 non-null    int64
#  5   용달 화물자동차 운송업 종사자수     447 non-null    int64
#  6   부동산 중개 및 대리업 사업체수     447 non-null    int64
#  7   부동산 중개 및 대리업 종사자수     447 non-null    int64
#  8   두발미용업 사업체수            447 non-null    int64
#  9   두발미용업 종사자수            447 non-null    int64
#  10  커피전문점 사업체수            447 non-null    int64
#  11  커피전문점 종사자수            447 non-null    int64
#  12  남녀용 겉옷 및 셔츠 도매업 사업체수  447 non-null    int64
#  13  남녀용 겉옷 및 셔츠 도매업 종사자수  447 non-null    int64
#  14  기타주점업 사업체수            447 non-null    int64
# ...

# %%
택시운송업 사업체수 한식 일반 음식점업 사업체수 용달 화물자동차 운송업 사업체수 부동산 중개 및 대리업 사업체수
두발미용업 사업체수 커피전문점 사업체수 남녀용 겉옷 및 셔츠 도매업 사업체수 기타주점업 사업체수 기타주점업 사업체수
일반 교과 학원 사업체수 한식 육류요리 전문점 사업체수

# %%
# 저장해둔 구 열과 병합
seoul_business1=pd.concat([seoul_business,seoul_business_gu],axis=1)

# %%
seoul_business1.head()
# Out:
#    택시운송업 사업체수  택시운송업 종사자수  한식 일반 음식점업 사업체수  한식 일반 음식점업 종사자수  \
# 0           7           7              230              982
# 1           5           5               42              145
# 2          22          22               26              100
# 3          10          10               31              116
# 4          10          10               10               26
#
#    용달 화물자동차 운송업 사업체수  용달 화물자동차 운송업 종사자수  부동산 중개 및 대리업 사업체수  부동산 중개 및 대리업 종사자수  \
# 0                 12                 12                 57                 96
# 1                  4                  4                  9                 10
# 2                  9                  9                 17                 26
# 3                 11                 11                 33                 52
# 4                410                416                 12                 17
#
#    두발미용업 사업체수  두발미용업 종사자수  ...  커피전문점 종사자수  남녀용 겉옷 및 셔츠 도매업 사업체수  \
# 0          28          66  ...         525                     2
# ...

# %%
seoul_business1=seoul_business1.groupby('자치구').sum()

# %%
seoul_business1['등록업종총합']=seoul_business1.sum(axis=1)

# %%
seoul_business1.head()
# Out:
#      택시운송업 사업체수  택시운송업 종사자수  한식 일반 음식점업 사업체수  한식 일반 음식점업 종사자수  \
# 자치구
# 강남구        3592        5034             4830            22972
# 강동구        6590        9960             2202             6776
# 강북구        3426        5178             1930             5326
# 강서구        7470       13844             2650             9168
# 관악구        2572        4054             2452             7378
#
#      용달 화물자동차 운송업 사업체수  용달 화물자동차 운송업 종사자수  부동산 중개 및 대리업 사업체수  \
# 자치구
# 강남구                890                974               4674
# 강동구               3056               3132               2376
# 강북구               2048               2060               1178
# 강서구               3598               3724               2622
# 관악구               3158               3200               2020
#
#      부동산 중개 및 대리업 종사자수  두발미용업 사업체수  두발미용업 종사자수  ...  커피전문점 종사자수  \
# 자치구                                             ...
# 강남구              13016        2482       12510  ...       14546
# ...

# %%
cor=seoul_business1.corr()
plt.figure(figsize=(10,8))
sns.heatmap(cor, annot=True)
plt.title('상관관계', size=30)
# Out:
# Text(0.5, 1.0, '상관관계')

# %%
seoul_business1=seoul_business1[['택시운송업 사업체수',
                                 '한식 일반 음식점업 사업체수',
                                 '용달 화물자동차 운송업 사업체수',
                                 '부동산 중개 및 대리업 사업체수',
                                 '두발미용업 사업체수',
                                 '커피전문점 사업체수',
                                 '남녀용 겉옷 및 셔츠 도매업 사업체수',
                                 '기타주점업 사업체수',
                                 '일반 교과 학원 사업체수', 
                                 '한식 육류요리 전문점 사업체수']]

# %%
cor=seoul_business1.corr()
plt.figure(figsize=(10,8))
sns.heatmap(cor, annot=True)
plt.title('상관관계', size=30)
# Out:
# C:\Users\shjo\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# Text(0.5, 1.0, '상관관계')
# C:\Users\shjo\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import scipy.stats as stats
stats.pearsonr(seoul_business1['택시운송업 사업체수'],seoul_business1['용달 화물자동차 운송업 사업체수'])
# 택시 + 용달
# Out:
# (0.82287469302437, 4.43612942438371e-07)

# %%
print(stats.pearsonr(seoul_business1['한식 일반 음식점업 사업체수'],seoul_business1['커피전문점 사업체수']))
print(stats.pearsonr(seoul_business1['한식 일반 음식점업 사업체수'],seoul_business1['한식 육류요리 전문점 사업체수']))
print(stats.pearsonr(seoul_business1['커피전문점 사업체수'],seoul_business1['한식 육류요리 전문점 사업체수']))
# 한식일반 + 한식육류 + 커피
# Out:
# (0.8757607462809938, 9.870733715785283e-09)
# (0.8136430718647973, 7.581492574348113e-07)
# (0.8250610363604596, 3.8898425106805417e-07)

# %%
seoul_business1['택시,용달 운송업 사업체수']=seoul_business1['택시운송업 사업체수']+seoul_business1['용달 화물자동차 운송업 사업체수']
seoul_business1=seoul_business1.drop(columns=['택시운송업 사업체수','용달 화물자동차 운송업 사업체수'])

# %%
seoul_business1['한식 음식점,커피 전문점 사업체수']=seoul_business1['한식 일반 음식점업 사업체수']+seoul_business1['커피전문점 사업체수']+seoul_business1['한식 육류요리 전문점 사업체수']
seoul_business1=seoul_business1.drop(columns=['한식 일반 음식점업 사업체수','커피전문점 사업체수','한식 육류요리 전문점 사업체수'])

# %%
seoul_business1['등록업종총합']=seoul_business1.sum(axis=1)

# %%
seoul_business1.head()
# Out:
#      부동산 중개 및 대리업 사업체수  두발미용업 사업체수  남녀용 겉옷 및 셔츠 도매업 사업체수  기타주점업 사업체수  \
# 자치구
# 강남구               4674        2482                   768        1426
# 강동구               2376        1800                   118        1178
# 강북구               1178        1346                    80        1160
# 강서구               2622        2030                   156        1588
# 관악구               2020        1790                    62        1316
#
#      일반 교과 학원 사업체수  택시,용달 운송업 사업체수  한식 음식점,커피 전문점 사업체수  등록업종총합
# 자치구
# 강남구           2852            4482                9732   26416
# 강동구           1240            9646                4150   20508
# 강북구            440            5474                3370   13048
# 강서구           1344           11068                5192   24000
# 관악구            708            5730                4458   16084

# %%
# 구별 10개 등록업종의 사업체 수의 총 합
plt.figure(figsize=(20,10))
plt.plot('등록업종총합',data=seoul_business1)

# %%
seoul_business1=seoul_business1.reset_index()

# %%
seoul_business1.head()
# Out:
#    자치구  부동산 중개 및 대리업 사업체수  두발미용업 사업체수  남녀용 겉옷 및 셔츠 도매업 사업체수  기타주점업 사업체수  \
# 0  강남구               4674        2482                   768        1426
# 1  강동구               2376        1800                   118        1178
# 2  강북구               1178        1346                    80        1160
# 3  강서구               2622        2030                   156        1588
# 4  관악구               2020        1790                    62        1316
#
#    일반 교과 학원 사업체수  택시,용달 운송업 사업체수  한식 음식점,커피 전문점 사업체수  등록업종총합
# 0           2852            4482                9732   26416
# 1           1240            9646                4150   20508
# 2            440            5474                3370   13048
# 3           1344           11068                5192   24000
# 4            708            5730                4458   16084

# %%
# 해당 데이터프레임을 'df_seoul_business.csv' 파일로 저장하세요.
seoul_business1.to_csv("df_seoul_business.csv", index = False)

# %% [markdown]
# ---

# %% [markdown]
# # 3.데이터 분석하기
# + KeyPoint : 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별할 수 있다.
#   * 데이터들의 패턴 탐색
#   * 변수들간의 관계 파악

# %%
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt

# 한글 폰트 오류 해결
from matplotlib import font_manager,rc
font_path="./malgun.ttf"
font_name=font_manager.FontProperties(fname=font_path).get_name()
rc('font',family=font_name)

# %% [markdown]
# #### [실습문제4] 데이터 분포 알아보기
# * 다양한 변수를 기준으로 그래프를 그려보고 인사이트를 도출해보세요.

# %% [markdown]
# # 위 차트를 통해 알게된 사실을 정리해봅시다.
# # 1. 서울 시 구별 등록 업종 상위 10개의 사업체,종사자 수가 가장 많은 구는 강남구,중구
# # 2. 그러나 10개의 업종 전체의 합을 사용하는 것은 틀릴 수도 있음. 10개의 업종 중 정류장, 노선의 수와 연관성을 보이는 업종들의 비율로 봐야 할 것 같음.

# %% [markdown]
# ---
